# %%
len('abc')
# Out:
# 3

# %%
import random

# %%
random.randint(1,4)
# Out:
# 2

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001BA6A3FD7E0>>

# %%
type(random.randint)
# Out:
# method

# %%
def add(a,b):
    return a+b

# %%
import lesson10
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import lesson10
#
# ModuleNotFoundError: No module named 'lesson10'
